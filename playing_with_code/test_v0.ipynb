# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
pwd
# Out:
# '/raid/home/myang349/recsys-filterbubbles'

# %%
# %run tracin_lstm.py
# Out:
# Device is  cpu
# Loading data
# Data looks like
#     user_id    stream_id  streamer_name  start_time  stop_time  community
# 0        1  33842865744              0         154        156          5
# 1        1  33846768288              1         166        169          5
# 2        1  33886469056              0         587        588          5
# 3        1  33887624992              2         589        591          5
# 4        1  33890145056              3         591        594          5
# Cleaned data looks like
#     user_id  streamer_name  stop_time
# 0        1              0        156
# 1        1              1        169
# 2        1              0        588
# 3        1              2        591
# 4        1              3        594
# Preprocessing Data
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /raid/home/myang349/recsys-filterbubbles/tracin_lstm.py in <module>
#      53 print("Preprocessing Data")
#      54 original_data = train_test_split(data=data)
# ---> 55 (train,test), train_items, test_items = sequence_generator(original_data,look_back)
#      56 test_ground_truth = {i:test[i][1] for i in range(len(test))}
#      57
#
# ValueError: too many values to unpack (expected 3)

# %%
train,test, train_items, test_items = sequence_generator(original_data,look_back)

# %%
set(test_items)
# Out:
# {0,
#  2,
#  3,
#  5,
#  9,
#  11,
#  12,
#  13,
#  14,
#  15,
#  16,
#  17,
#  19,
#  20,
#  21,
#  24,
#  27,
#  31,
#  32,
#  33,
#  34,
#  36,
#  38,
#  39,
#  40,
#  41,
#  42,
#  43,
#  45,
#  46,
#  47,
#  50,
#  51,
#  52,
#  54,
#  55,
#  60,
#  62,
#  63,
#  64,
#  66,
#  67,
#  69,
#  70,
#  71,
#  72,
#  73,
#  75,
#  78,
#  79,
#  80,
#  83,
#  84,
#  85,
#  94,
#  98,
#  99,
#  100,
#  101,
#  102,
#  104,
#  106,
#  108,
#  111,
#  112,
#  113,
#  114,
#  115,
#  116,
#  117,
#  119,
#  121,
#  123,
#  124,
#  125,
#  129,
#  131,
#  132,
#  133,
#  134,
#  135,
#  139,
#  140,
#  141,
#  142,
#  144,
#  145,
#  147,
#  148,
#  149,
#  152,
#  153,
#  154,
#  155,
#  156,
#  157,
#  158,
#  159,
#  160,
#  161,
#  162,
#  163,
#  164,
#  165,
#  167,
#  168,
#  169,
#  175,
#  176,
#  178,
#  179,
#  180,
#  181,
#  183,
#  185,
#  187,
#  191,
#  192,
#  194,
#  195,
#  196,
#  198,
#  199,
#  202,
#  204,
#  205,
#  206,
#  207,
#  208,
#  209,
#  212,
#  215,
#  217,
#  218,
#  223,
#  224,
#  226,
#  228,
#  229,
#  233,
#  235,
#  236,
#  237,
#  238,
#  239,
#  243,
#  244,
#  245,
#  246,
#  248,
#  252,
#  253,
#  254,
#  255,
#  257,
#  263,
#  264,
#  267,
#  269,
#  270,
#  271,
#  272,
#  277,
#  281,
#  286,
#  287,
#  288,
#  290,
#  291,
#  292,
#  294,
#  296,
#  297,
#  298,
#  299,
#  301,
#  303,
#  305,
#  306,
#  308,
#  309,
#  311,
#  314,
#  317,
#  319,
#  322,
#  327,
#  330,
#  335,
#  336,
#  337,
#  340,
#  342,
#  343,
#  344,
#  345,
#  351,
#  353,
#  355,
#  358,
#  360,
#  363,
#  364,
#  365,
#  368,
#  369,
#  370,
#  371,
#  373,
#  374,
#  376,
#  382,
#  383,
#  386,
#  388,
#  390,
#  391,
#  393,
#  395,
#  398,
#  399,
#  400,
#  401,
#  403,
#  404,
#  405,
#  407,
#  410,
#  411,
#  412,
#  414,
#  415,
#  416,
#  418,
#  419,
#  421,
#  422,
#  428,
#  429,
#  430,
#  431,
#  434,
#  435,
#  437,
#  440,
#  445,
#  446,
#  450,
#  454,
#  456,
#  459,
#  460,
#  463,
#  464,
#  465,
#  466,
#  467,
#  468,
#  469,
#  470,
#  471,
#  472,
#  474,
#  477,
#  478,
#  480,
#  482,
#  487,
#  492,
#  494,
#  495,
#  501,
#  502,
#  504,
#  505,
#  506,
#  507,
#  509,
#  511,
#  513,
#  514,
#  516,
#  519,
#  520,
#  522,
#  523,
#  526,
#  528,
#  533,
#  536,
#  541,
#  542,
#  543,
#  545,
#  546,
#  547,
#  551,
#  553,
#  555,
#  563,
#  566,
#  570,
#  575,
#  576,
#  578,
#  580,
#  581,
#  583,
#  591,
#  593,
#  595,
#  596,
#  598,
#  604,
#  606,
#  608,
#  609,
#  611,
#  614,
#  615,
#  616,
#  617,
#  619,
#  620,
#  623,
#  624,
#  630,
#  631,
#  633,
#  634,
#  635,
#  636,
#  640,
#  641,
#  643,
#  644,
#  645,
#  651,
#  652,
#  653,
#  654,
#  655,
#  656,
#  657,
#  659,
#  660,
#  664,
#  665,
#  666,
#  667,
#  670,
#  674,
#  677,
#  679,
#  680,
#  682,
#  685,
#  686,
#  687,
#  688,
#  692,
#  693,
#  694,
#  696,
#  699,
#  702,
#  705,
#  711,
#  713,
#  714,
#  716,
#  717,
#  719,
#  720,
#  722,
#  726,
#  728,
#  732,
#  734,
#  736,
#  738,
#  741,
#  743,
#  749,
#  753,
#  754,
#  756,
#  757,
#  758,
#  759,
#  761,
#  763,
#  764,
#  766,
#  768,
#  770,
#  774,
#  780,
#  781,
#  783,
#  784,
#  786,
#  788,
#  789,
#  790,
#  792,
#  793,
#  796,
#  798,
#  800,
#  802,
#  804,
#  806,
#  808,
#  810,
#  820,
#  821,
#  822,
#  823,
#  825,
#  826,
#  827,
#  834,
#  835,
#  838,
#  844,
#  845,
#  847,
#  848,
#  849,
#  851,
#  853,
#  854,
#  855,
#  859,
#  862,
#  864,
#  865,
#  866,
#  873,
#  875,
#  881,
#  882,
#  884,
#  885,
#  887,
#  888,
#  891,
#  892,
#  893,
#  895,
#  896,
#  904,
#  906,
#  909,
#  917,
#  920,
#  924,
#  925,
#  926,
#  927,
#  933,
#  934,
#  935,
#  936,
#  938,
#  941,
#  942,
#  944,
#  946,
#  948,
#  949,
#  950,
#  955,
#  960,
#  961,
#  963,
#  971,
#  972,
#  973,
#  977,
#  982,
#  983,
#  985,
#  986,
#  988,
#  989,
#  990,
#  994,
#  995,
#  996,
#  997,
#  1001,
#  1002,
#  1004,
#  1005,
#  1009,
#  1011,
#  1012,
#  1015,
#  1016,
#  1018,
#  1021,
#  1024,
#  1026,
#  1027,
#  1029,
#  1033,
#  1037,
#  1039,
#  1040,
#  1041,
#  1044,
#  1045,
#  1046,
#  1047,
#  1048,
#  1050,
#  1052,
#  1053,
#  1054,
#  1055,
#  1056,
#  1057,
#  1058,
#  1059,
#  1060,
#  1064,
#  1067,
#  1069,
#  1070,
#  1071,
#  1072,
#  1075,
#  1076,
#  1084,
#  1086,
#  1087,
#  1090,
#  1091,
#  1092,
#  1097,
#  1100,
#  1101,
#  1104,
#  1107,
#  1112,
#  1114,
#  1115,
#  1116,
#  1117,
#  1119,
#  1122,
#  1123,
#  1126,
#  1127,
#  1129,
#  1134,
#  1141,
#  1142,
#  1143,
#  1146,
#  1147,
#  1148,
#  1149,
#  1153,
#  1154,
#  1155,
#  1156,
#  1159,
#  1162,
#  1166,
#  1170,
#  1173,
#  1177,
#  1179,
#  1181,
#  1185,
#  1186,
#  1189,
#  1191,
#  1193,
#  1195,
#  1199,
#  1201,
#  1202,
#  1205,
#  1206,
#  1217,
#  1222,
#  1226,
#  1229,
#  1233,
#  1235,
#  1236,
#  1239,
#  1240,
#  1241,
#  1242,
#  1245,
#  1248,
#  1250,
#  1253,
#  1255,
#  1272,
#  1283,
#  1286,
#  1293,
#  1294,
#  1297,
#  1299,
#  1302,
#  1303,
#  1308,
#  1309,
#  1310,
#  1311,
#  1316,
#  1317,
#  1336,
#  1345,
#  1350,
#  1353,
#  1355,
#  1356,
#  1358,
#  1361,
#  1363,
#  1365,
#  1367,
#  1368,
#  1369,
#  1372,
#  1375,
#  1379,
#  1384,
#  1385,
#  1387,
#  1392,
#  1393,
#  1396,
#  1401,
#  1403,
#  1409,
#  1410,
#  1413,
#  1414,
#  1415,
#  1419,
#  1422,
#  1427,
#  1428,
#  1431,
#  1433,
#  1435,
#  1436,
#  1437,
#  1442,
#  1444,
#  1446,
#  1457,
#  1458,
#  1462,
#  1466,
#  1470,
#  1472,
#  1473,
#  1474,
#  1476,
#  1478,
#  1483,
#  1485,
#  1488,
#  1490,
#  1491,
#  1496,
#  1497,
#  1499,
#  1500,
#  1502,
#  1506,
#  1508,
#  1510,
#  1514,
#  1515,
#  1518,
#  1520,
#  1521,
#  1524,
#  1531,
#  1533,
#  1534,
#  1538,
#  1540,
#  1541,
#  1542,
#  1548,
#  1560,
#  1563,
#  1565,
#  1571,
#  1574,
#  1579,
#  1592,
#  1595,
#  1599,
#  1601,
#  1605,
#  1608,
#  1616,
#  1624,
#  1626,
#  1628,
#  1631,
#  1632,
#  1636,
#  1637,
#  1638,
#  1640,
#  1641,
#  1643,
#  1644,
#  1649,
#  1652,
#  1654,
#  1658,
#  1661,
#  1665,
#  1667,
#  1669,
#  1670,
#  1672,
#  1673,
#  1676,
#  1679,
#  1688,
#  1690,
#  1696,
#  1697,
#  1699,
#  1700,
#  1702,
#  1703,
#  1714,
#  1718,
#  1728,
#  1730,
#  1731,
#  1732,
#  1737,
#  1744,
#  1745,
#  1747,
#  1749,
#  1755,
#  1756,
#  1760,
#  1763,
#  1765,
#  1767,
#  1777,
#  1783,
#  1786,
#  1792,
#  1795,
#  1796,
#  1802,
#  1804,
#  1806,
#  1809,
#  1812,
#  1813,
#  1815,
#  1824,
#  1833,
#  1836,
#  1839,
#  1842,
#  1847,
#  1850,
#  1861,
#  1862,
#  1864,
#  1869,
#  1875,
#  1876,
#  1877,
#  1891,
#  1893,
#  1896,
#  1898,
#  1899,
#  1901,
#  1905,
#  1907,
#  1909,
#  1911,
#  1912,
#  1915,
#  1919,
#  1920,
#  1921,
#  1925,
#  1927,
#  1931,
#  1933,
#  1934,
#  1935,
#  1938,
#  1939,
#  1940,
#  1942,
#  1943,
#  1952,
#  1963,
#  1968,
#  1970,
#  1978,
#  1983,
#  1984,
#  1985,
#  1988,
#  1993,
#  1994,
#  1999,
#  2004,
#  2006,
#  2009,
#  2011,
#  2013,
#  2015,
#  2017,
#  2018,
#  2020,
#  2038,
#  2041,
#  2042,
#  2043,
#  2045,
#  2051,
#  2052,
#  2056,
#  2057,
#  2058,
#  2062,
#  2065,
#  2066,
#  2071,
#  2073,
#  2078,
#  2079,
#  2083,
#  2086,
#  2087,
#  2089,
#  2098,
#  2099,
#  2100,
#  2107,
#  2112,
#  2113,
#  2114,
#  2115,
#  2119,
#  2121,
#  2122,
#  2123,
#  2124,
#  2125,
#  2129,
#  2130,
#  2135,
#  2136,
#  2138,
#  2144,
#  2147,
#  2149,
#  2150,
#  2151,
#  2154,
#  2155,
#  2158,
#  2159,
#  2161,
#  2168,
#  2170,
#  2182,
#  2185,
#  2186,
#  2190,
#  2191,
#  2198,
#  2206,
#  2209,
#  2210,
#  2211,
#  2213,
#  2216,
#  2221,
#  2230,
#  2234,
#  2236,
#  2247,
#  2248,
#  2252,
#  2257,
#  2262,
#  2269,
#  2270,
#  2273,
#  2274,
#  2283,
#  2290,
#  2292,
#  2294,
#  2302,
#  2307,
#  2312,
#  2315,
#  2316,
#  2319,
#  2322,
#  2324,
#  2333,
#  2338,
#  2347,
#  2349,
#  2353,
#  2356,
#  2358,
#  2360,
#  2370,
#  2373,
#  2375,
#  2379,
#  2384,
#  2385,
#  2394,
#  2395,
#  2398,
#  2400,
#  2407,
#  2417,
#  2419,
#  2436,
#  2437,
#  2443,
#  2444,
#  2445,
#  2447,
#  2448,
#  2461,
#  2462,
#  2466,
#  2467,
#  2468,
#  2470,
#  2472,
#  2473,
#  2474,
#  2477,
#  2478,
#  2480,
#  2482,
#  2487,
#  2493,
#  2502,
#  2513,
#  2521,
#  2522,
#  2523,
#  2524,
#  2531,
#  2535,
#  2545,
#  2553,
#  2556,
#  2561,
#  2564,
#  2565,
#  2568,
#  2570,
#  2573,
#  2576,
#  2578,
#  2579,
#  2587,
#  2589,
#  2595,
#  2598,
#  2599,
#  2601,
#  2605,
#  2607,
#  2618,
#  2624,
#  2627,
#  2629,
#  2630,
#  2641,
#  ...}

# %%
torch.cuda.is_available()
# Out:
# False

# %%
torch.cuda.current_device()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_684051/361484350.py in <module>
# ----> 1 torch.cuda.current_device()
#
# ~/miniconda3/envs/cse_v0/lib/python3.9/site-packages/torch/cuda/__init__.py in current_device()
#     386 def current_device() -> int:
#     387     r"""Returns the index of a currently selected device."""
# --> 388     _lazy_init()
#     389     return torch._C._cuda_getDevice()
#     390
#
# ~/miniconda3/envs/cse_v0/lib/python3.9/site-packages/torch/cuda/__init__.py in _lazy_init()
#     162                 "multiprocessing, you must use the 'spawn' start method")
#     163         if not hasattr(torch._C, '_cuda_getDeviceCount'):
# --> 164             raise AssertionError("Torch not compiled with CUDA enabled")
#     165         if _cudart is None:
#     166             raise AssertionError(
#
# AssertionError: Torch not compiled with CUDA enabled
